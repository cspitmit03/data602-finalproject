# %% [markdown]
# Let's import our packages

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.api as sm
import seaborn as sns

# %% [markdown]
# Download our dataset with responses and predictors.

# %%
predPath = r"C:\Users\asher\Documents\GitHub\data602-finalproject\predictorsDF.csv"
predictorsDF = pd.read_csv(predPath)

# %%
predictorsDF.columns
# Out:
# Index(['Date', 'BGT', 'Broad', 'Elliot', 'Fremont', 'MTS', 'NW58', 'Second',
#        'Spokane', 'Thirty', 'TwoSix', 'Sunlight', 'Weekend', 'isMay', 'TempHi',
#        'TempAvg', 'TempLow', 'DewHigh', 'DewAvg', 'DewLow', 'HumidHi',
#        'HumidAvg', 'HumidLow', 'PressHigh', 'PressAvg', 'PressLow', 'VisHigh',
#        'VisAvg', 'VisLow', 'WindAvg', 'WindLow', 'WindHigh', 'Precip',
#        'Events', 'Holiday', 'BusinessDay', 'WeekNumber', 'Friday'],
#       dtype='object')

# %%
# Create data
predictor = "Sunlight"
x = predictorsDF[predictor]
y = predictorsDF["Fremont"]
colors = (0,0,0)
area = np.pi*1
 
# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title(predictor)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Create data
predictor = "TempHi"
x = predictorsDF[predictor]
y = predictorsDF["Fremont"]
colors = (0,0,0)
area = np.pi*1
 
# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title(predictor)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Create data
predictor = "Precip"
x = predictorsDF[predictor]
y = predictorsDF["Fremont"]
colors = (0,0,0)
area = np.pi*1
 
# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title(predictor)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
plt.hist(predictorsDF["Sunlight"])
plt.show()

# %%
# Create data
predictor = "Precip"
x = predictorsDF[predictor]
y = predictorsDF["Fremont"]
colors = (0,0,0)
area = np.pi*1
 
# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title(predictor)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Create data
predictor = "logPrecip"
x = np.log(predictorsDF["Precip"]+1)
predictorsDF[predictor] = x
y = predictorsDF["Fremont"]
colors = (0,0,0)
area = np.pi*1
 
# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title(predictor)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Create data
predictor = "WeekNumber"
x = predictorsDF[predictor]
y = predictorsDF["Fremont"]
colors = (0,0,0)
area = np.pi*1
 
# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title(predictor)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Create data
predictor = "WindAvg"
x = predictorsDF[predictor]
y = predictorsDF["Fremont"]
colors = (0,0,0)
area = np.pi*1
 
# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title(predictor)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
sns.set(style = "ticks")
df = predictorsDF.loc[:,["Fremont", "Sunlight", "Precip", "TempHi"]]
sns.pairplot(df)
plt.show()

# %%
predictorsDF.columns
# Out:
# Index(['Date', 'BGT', 'Broad', 'Elliot', 'Fremont', 'MTS', 'NW58', 'Second',
#        'Spokane', 'Thirty', 'TwoSix', 'Sunlight', 'Weekend', 'isMay', 'TempHi',
#        'TempAvg', 'TempLow', 'DewHigh', 'DewAvg', 'DewLow', 'HumidHi',
#        'HumidAvg', 'HumidLow', 'PressHigh', 'PressAvg', 'PressLow', 'VisHigh',
#        'VisAvg', 'VisLow', 'WindAvg', 'WindLow', 'WindHigh', 'Precip',
#        'Events', 'Holiday', 'BusinessDay', 'WeekNumber', 'Friday',
#        'logPrecip'],
#       dtype='object')

# %%
fit1 = smf.ols('Fremont ~ Sunlight + logPrecip + TempHi + WindAvg + BusinessDay + WeekNumber', 
               data=predictorsDF).fit()
print(fit1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Fremont   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     1557.
# Date:                Fri, 24 Nov 2017   Prob (F-statistic):               0.00
# Time:                        08:28:20   Log-Likelihood:                -14302.
# No. Observations:                1855   AIC:                         2.862e+04
# Df Residuals:                    1848   BIC:                         2.866e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -1968.8240     80.084    -24.585      0.000   -2125.888   -1811.760
# ...

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(fit1, "WeekNumber", fig=fig)
plt.show()

# %%
x = predictorsDF[""]

# %%
indices = [11, 12] # Sunlight and Weekend

X_train = predictorsDF.iloc[:, indices]
X_test = predictorsDF.iloc[:, indices]
y_train = predictorsDF.Fremont[:]
y_test = predictorsDF.Fremont[:]

# %%
Sunlight = np.array(predictorsDF["Sunlight"])
Weekend = np.array(predictorsDF["Weekend"])
Sunlight = Sunlight.reshape(len(predictorsDF["Sunlight"]), 1)
Weekend = Weekend.reshape(len(predictorsDF["Weekend"]), 1)
a = np.hstack([Sunlight,Weekend])

# %%
a = np.array([predictorsDF["Sunlight"], predictorsDF["Weekend"]])
a = a.transpose()

# %%
a = []
for i in range(0, len(predictorsDF["Sunlight"])):
    a.append([predictorsDF["Sunlight"][i], # Hours of sunlight per day
              predictorsDF["Weekend"][i], # True if weekend, where ridership is lower
              predictorsDF["Precip"][i]]) # Inches rainfall

a = np.array(a)
b = np.array(predictorsDF["Fremont"])

a = a.reshape(len(a), 3)
b = b.reshape(len(predictorsDF["Fremont"]), 1)

clf = linear_model.LinearRegression()
clf.fit(a, b)

print(clf.coef_)
# Out:
# [[  284.69696879 -1675.76215245 -1142.40705898]]

# %%
X = predictorsDF.loc[:, ["Sunlight", "Weekend", "Precip"]] # Table of predictors
y = predictorsDF.Fremont
predictions = clf.predict(X)
r2_score(y, predictions)
# Out:
# 0.74050696244661707

# %%
regr = linear_model.LinearRegression()
Sunlight = predictorsDF.Sunlight.values.reshape(-1, 1)
Precip = predictorsDF.Precip.values.reshape(-1,1)
Fremont = predictorsDF.Fremont.values.reshape(-1, 1)
regr.fit(Sunlight, Fremont)

predictions = regr.predict(Sunlight)
